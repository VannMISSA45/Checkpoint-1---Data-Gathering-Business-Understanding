# %% [markdown]
# # Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Membaca Data

# %%
df = pd.read_csv("/content/train.csv")
df
# Out:
#     WIN_20180925_17_08_43_Pro_Left_Swipe_new;Left_Swipe_new;0
# 0    WIN_20180925_17_18_28_Pro_Left_Swipe_new;Left_...
# 1    WIN_20180925_17_18_56_Pro_Left_Swipe_new;Left_...
# 2    WIN_20180925_17_19_51_Pro_Left_Swipe_new;Left_...
# 3    WIN_20180925_17_20_14_Pro_Left_Swipe_new;Left_...
# 4    WIN_20180925_17_21_28_Pro_Left_Swipe_new;Left_...
# ..                                                 ...
# 657  WIN_20180907_16_38_23_Pro_Thumbs Up_new;Thumbs...
# 658  WIN_20180907_16_41_09_Pro_Thumbs Up_new;Thumbs...
# 659  WIN_20180907_16_42_05_Pro_Thumbs Up_new;Thumbs...
# 660  WIN_20180907_16_42_55_Pro_Thumbs Up_new;Thumbs...
# 661  WIN_20180907_16_43_39_Pro_Thumbs Up_new;Thumbs...
#
# [662 rows x 1 columns]

# %%
df_train.columns = ['File_Name', 'Action', 'Value']

# %%
plt.figure(figsize=(8, 5))
plt.bar(df_train['Action'].value_counts().index, df_train['Action'].value_counts().values, color='blue')
plt.title('Jumlah Tindakan Berdasarkan Kategori')
plt.xlabel('Kategori Tindakan')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8, 5))
sns.countplot(x='Action', data=df_train, hue="Value", palette='pastel')
plt.title('Jumlah Tindakan Berdasarkan Kategori dan Nilai')
plt.xlabel('Kategori Tindakan')
plt.ylabel('Jumlah')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(6, 6))
plt.pie(df_train['Action'].value_counts(), labels=df_train['Action'].value_counts().index, autopct='%1.1f%%', colors=['lightcoral', 'lightblue', 'lightgreen', 'gold'])
plt.title('Distribusi Kategori Tindakan')
plt.show()
