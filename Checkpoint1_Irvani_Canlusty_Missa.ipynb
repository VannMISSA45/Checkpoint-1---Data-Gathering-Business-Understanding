# %% [markdown]
# # **Membuat Library**

# %%
import pandas as pd

# %% [markdown]
# # Membaca Data

# %%
file_path = "/content/drive/MyDrive/Folder MINPRO AVD/train.csv"

df = pd.read_csv(file_path)
df
# Out:
#     WIN_20180925_17_08_43_Pro_Left_Swipe_new;Left_Swipe_new;0
# 0    WIN_20180925_17_18_28_Pro_Left_Swipe_new;Left_...
# 1    WIN_20180925_17_18_56_Pro_Left_Swipe_new;Left_...
# 2    WIN_20180925_17_19_51_Pro_Left_Swipe_new;Left_...
# 3    WIN_20180925_17_20_14_Pro_Left_Swipe_new;Left_...
# 4    WIN_20180925_17_21_28_Pro_Left_Swipe_new;Left_...
# ..                                                 ...
# 657  WIN_20180907_16_38_23_Pro_Thumbs Up_new;Thumbs...
# 658  WIN_20180907_16_41_09_Pro_Thumbs Up_new;Thumbs...
# 659  WIN_20180907_16_42_05_Pro_Thumbs Up_new;Thumbs...
# 660  WIN_20180907_16_42_55_Pro_Thumbs Up_new;Thumbs...
# 661  WIN_20180907_16_43_39_Pro_Thumbs Up_new;Thumbs...
#
# [662 rows x 1 columns]

# %% [markdown]
# # Menyimpan data sebagai file ecxel

# %%
# print("Jika ingin menampilkan Beberapa Row Data:\n", df.head(10))

# print("\nJika ingin menampilkan Keseluruhan Data:\n", df)

output_path = "train.xlsx"
df.to_excel(output_path, index=False)

print("\nData berhasil disimpan sebagai file Excel:", output_path)
# Out:
# Data berhasil disimpan sebagai file Excel: train.xlsx

# %% [markdown]
# # Pengecekan struktur data

# %%
print("Jika ingin menampilkan Beberapa Row Data:")
df.head(3)

print("\nJika ingin menampilkan Keseluruhan Data:")
df

print("\nMenampilkan 5 baris pertama dengan df.head():")
df.head()

print("\nMenampilkan 5 baris terakhir dengan df.tail():")
df.tail()
# Out:
# Jika ingin menampilkan Beberapa Row Data:
#
# Jika ingin menampilkan Keseluruhan Data:
#
# Menampilkan 5 baris pertama dengan df.head():
#
# Menampilkan 5 baris terakhir dengan df.tail():
#     WIN_20180925_17_08_43_Pro_Left_Swipe_new;Left_Swipe_new;0
# 657  WIN_20180907_16_38_23_Pro_Thumbs Up_new;Thumbs...
# 658  WIN_20180907_16_41_09_Pro_Thumbs Up_new;Thumbs...
# 659  WIN_20180907_16_42_05_Pro_Thumbs Up_new;Thumbs...
# 660  WIN_20180907_16_42_55_Pro_Thumbs Up_new;Thumbs...
# 661  WIN_20180907_16_43_39_Pro_Thumbs Up_new;Thumbs...

# %%
print("\nMenampilkan ringkasan informasi dataset dengan df.info():")
df.info()

print("\nMenampilkan jumlah baris dan kolom dengan df.shape:")
print(df.shape)

print("\nMenampilkan tipe data setiap kolom dengan df.dtypes:")
print(df.dtypes)
# Out:
# Menampilkan ringkasan informasi dataset dengan df.info():
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 662 entries, 0 to 661
# Data columns (total 1 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   WIN_20180925_17_08_43_Pro_Left_Swipe_new;Left_Swipe_new;0  662 non-null    object
# dtypes: object(1)
# memory usage: 5.3+ KB
#
# Menampilkan jumlah baris dan kolom dengan df.shape:
# (662, 1)
#
# Menampilkan tipe data setiap kolom dengan df.dtypes:
# WIN_20180925_17_08_43_Pro_Left_Swipe_new;Left_Swipe_new;0    object
# dtype: object

# %%
df.describe()
# Out:
#        WIN_20180925_17_08_43_Pro_Left_Swipe_new;Left_Swipe_new;0
# count                                                 662
# unique                                                662
# top     WIN_20180925_17_18_28_Pro_Left_Swipe_new;Left_...
# freq                                                    1

# %% [markdown]
# # Mengecek struktur data

# %%
kolom_tertentu = "Right_Swipe_new"
if kolom_tertentu in df.columns:
    print(f"\nMenghitung jumlah kemunculan nilai unik dalam kolom '{kolom_tertentu}' dengan df['{kolom_tertentu}'].value_counts():")
    print(df[kolom_tertentu].value_counts())
else:
    print(f"\nKolom '{kolom_tertentu}' tidak ditemukan dalam dataset.")

print("\nMenghitung rata-rata dengan df.mean():")
print(df.mean(numeric_only=True))

print("\nMenghitung median dengan df.median():")
print(df.median(numeric_only=True))

print("\nMenghitung standar deviasi dengan df.std():")
print(df.std(numeric_only=True))

print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Kolom 'Right_Swipe_new' tidak ditemukan dalam dataset.
#
# Menghitung rata-rata dengan df.mean():
# Series([], dtype: float64)
#
# Menghitung median dengan df.median():
# Series([], dtype: float64)
#
# Menghitung standar deviasi dengan df.std():
# Series([], dtype: float64)
#
# Menghitung korelasi antar kolom numerik dengan df.corr():
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# # Data preparation

# %%
df
# Out:
#     WIN_20180925_17_08_43_Pro_Left_Swipe_new;Left_Swipe_new;0
# 0    WIN_20180925_17_18_28_Pro_Left_Swipe_new;Left_...
# 1    WIN_20180925_17_18_56_Pro_Left_Swipe_new;Left_...
# 2    WIN_20180925_17_19_51_Pro_Left_Swipe_new;Left_...
# 3    WIN_20180925_17_20_14_Pro_Left_Swipe_new;Left_...
# 4    WIN_20180925_17_21_28_Pro_Left_Swipe_new;Left_...
# ..                                                 ...
# 657  WIN_20180907_16_38_23_Pro_Thumbs Up_new;Thumbs...
# 658  WIN_20180907_16_41_09_Pro_Thumbs Up_new;Thumbs...
# 659  WIN_20180907_16_42_05_Pro_Thumbs Up_new;Thumbs...
# 660  WIN_20180907_16_42_55_Pro_Thumbs Up_new;Thumbs...
# 661  WIN_20180907_16_43_39_Pro_Thumbs Up_new;Thumbs...
#
# [662 rows x 1 columns]
